# %%
import cv2 as cv
import time
import os
from yolo_detector import YoloDetector
from tracker import Tracker

# %%
MODEL_PATH = "models/yolo11n"
VIDEO_PATH = 2
# VIDEO_PATH = "data/test/traffic.mp4"

def main():
    # Initialize YOLO and Deep SORT
    detector = YoloDetector(model_path=MODEL_PATH, confidence=0.3)
    print(detector.model.names)
    
    tracker = Tracker()

    # Video input source: webcam if integer, video file otherwise
    is_webcam = isinstance(VIDEO_PATH, int) or VIDEO_PATH.isdigit()
    cap = cv.VideoCapture(int(VIDEO_PATH)) if is_webcam else cv.VideoCapture(VIDEO_PATH)

    # Set webcam resolution (only applies to webcam)
    if is_webcam:
        cap.set(cv.CAP_PROP_FRAME_WIDTH, 1280)
        cap.set(cv.CAP_PROP_FRAME_HEIGHT, 720)

    if not cap.isOpened():
        print("Error: Unable to open video source.")
        return

    # Output filename
    if is_webcam:
        output_filename = "data/output/webcam_result.mp4"
    else:
        input_name = os.path.splitext(os.path.basename(VIDEO_PATH))[0]
        output_filename = f"data/output/{input_name}_output.mp4"

    # Get video properties
    fps = 5 if is_webcam else int(cap.get(cv.CAP_PROP_FPS)) or 25
    width = int(cap.get(cv.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv.VideoWriter_fourcc(*'mp4v')
    out = cv.VideoWriter(output_filename, fourcc, fps, (width, height))

    print(f"\n[INFO] Saving output to: {output_filename}")


    while True:
        ret, frame = cap.read()
        if not ret:
            break

        start_time = cv.getTickCount()

        frame_resized = cv.resize(frame, (540, 480), interpolation=cv.INTER_LINEAR)

        detections = detector.detect(frame_resized)

        scale_x = frame.shape[1] / frame_resized.shape[1]
        scale_y = frame.shape[0] / frame_resized.shape[0]

        scaled_detections = []
        for (bbox, class_number, conf) in detections:
            x, y, w, h = bbox
            x = int(x * scale_x)
            y = int(y * scale_y)
            w = int(w * scale_x)
            h = int(h * scale_y)
            scaled_detections.append(([x, y, w, h], class_number, conf))

        tracking_ids, boxes = tracker.track(scaled_detections, frame)

        for detection, tracking_id, bounding_box in zip(scaled_detections, tracking_ids, boxes):
            (bbox, class_number, conf) = detection
            if conf < 0.3:
                continue

            x1, y1, w, h = bbox
            class_name = detector.model.names[class_number]

            cv.rectangle(frame, (int(bounding_box[0]), int(bounding_box[1])),
                         (int(bounding_box[2]), int(bounding_box[3])), (0, 255, 0), 2)
            cv.putText(frame, f"{class_name} ID:{tracking_id}", (x1, y1 - 10),
                       cv.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

        end_time = cv.getTickCount()
        fps_value = cv.getTickFrequency() / (end_time - start_time)

        cv.putText(frame, f"FPS: {fps_value:.2f}", (20, 30),
                   cv.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

        cv.imshow("Detection", frame)
        out.write(frame)

        key = cv.waitKey(1) & 0xFF
        if key == ord("q") or key == 27:
            break

    cap.release()
    out.release()
    cv.destroyAllWindows()
    print("[INFO] Video processing complete.")

if __name__ == "__main__":
    main()
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#
# [INFO] Saving output to: data/output/webcam_result.mp4
#
# 0: 576x640 1 bed, 1 laptop, 88.3ms
# Speed: 2.7ms preprocess, 88.3ms inference, 1.4ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 82.3ms
# Speed: 3.2ms preprocess, 82.3ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 80.0ms
# Speed: 2.9ms preprocess, 80.0ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 81.8ms
# Speed: 2.9ms preprocess, 81.8ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 83.7ms
# Speed: 3.2ms preprocess, 83.7ms inference, 1.4ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 82.5ms
# Speed: 2.9ms preprocess, 82.5ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 79.3ms
# Speed: 3.2ms preprocess, 79.3ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 77.4ms
# Speed: 2.9ms preprocess, 77.4ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 72.9ms
# Speed: 3.1ms preprocess, 72.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 72.3ms
# Speed: 2.7ms preprocess, 72.3ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 96.9ms
# Speed: 3.4ms preprocess, 96.9ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 82.4ms
# Speed: 2.9ms preprocess, 82.4ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 book, 62.9ms
# Speed: 2.5ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 book, 72.5ms
# Speed: 2.8ms preprocess, 72.5ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 60.1ms
# Speed: 2.3ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 69.9ms
# Speed: 3.4ms preprocess, 69.9ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 106.4ms
# Speed: 3.1ms preprocess, 106.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 book, 80.1ms
# Speed: 3.7ms preprocess, 80.1ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 (no detections), 68.6ms
# Speed: 3.2ms preprocess, 68.6ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 keyboard, 70.9ms
# Speed: 3.1ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 70.4ms
# Speed: 2.7ms preprocess, 70.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 70.2ms
# Speed: 2.9ms preprocess, 70.2ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 tv, 2 mouses, 2 keyboards, 71.3ms
# Speed: 3.0ms preprocess, 71.3ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 mouses, 1 keyboard, 64.2ms
# Speed: 2.8ms preprocess, 64.2ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 tv, 1 mouse, 2 keyboards, 64.8ms
# Speed: 2.7ms preprocess, 64.8ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 73.8ms
# Speed: 3.0ms preprocess, 73.8ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 person, 1 tv, 1 mouse, 1 keyboard, 71.1ms
# Speed: 2.9ms preprocess, 71.1ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 tv, 1 mouse, 1 keyboard, 75.4ms
# Speed: 2.9ms preprocess, 75.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 tv, 1 mouse, 1 keyboard, 74.2ms
# Speed: 2.6ms preprocess, 74.2ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 79.4ms
# Speed: 3.1ms preprocess, 79.4ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 71.9ms
# Speed: 2.8ms preprocess, 71.9ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 74.6ms
# Speed: 2.8ms preprocess, 74.6ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 64.3ms
# Speed: 2.9ms preprocess, 64.3ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 tv, 1 mouse, 1 keyboard, 64.8ms
# Speed: 2.9ms preprocess, 64.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 tv, 1 mouse, 1 keyboard, 65.1ms
# Speed: 2.8ms preprocess, 65.1ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 65.6ms
# Speed: 2.9ms preprocess, 65.6ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 66.8ms
# Speed: 2.9ms preprocess, 66.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 73.9ms
# Speed: 2.7ms preprocess, 73.9ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 keyboard, 65.0ms
# Speed: 2.5ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 tv, 2 mouses, 1 keyboard, 61.8ms
# Speed: 2.4ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 62.7ms
# Speed: 2.2ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 laptops, 1 mouse, 1 keyboard, 79.1ms
# Speed: 3.4ms preprocess, 79.1ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 laptops, 1 mouse, 1 keyboard, 65.1ms
# Speed: 2.8ms preprocess, 65.1ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 74.6ms
# Speed: 2.8ms preprocess, 74.6ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 mouses, 2 keyboards, 75.8ms
# Speed: 2.8ms preprocess, 75.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 mouses, 2 keyboards, 68.0ms
# Speed: 2.8ms preprocess, 68.0ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 mouses, 2 keyboards, 1 book, 61.5ms
# Speed: 2.3ms preprocess, 61.5ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 2 keyboards, 1 book, 76.7ms
# Speed: 3.2ms preprocess, 76.7ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 76.3ms
# Speed: 2.8ms preprocess, 76.3ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 65.2ms
# Speed: 2.8ms preprocess, 65.2ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 74.8ms
# Speed: 3.1ms preprocess, 74.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 2 keyboards, 73.6ms
# Speed: 2.8ms preprocess, 73.6ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 74.8ms
# Speed: 3.1ms preprocess, 74.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 75.4ms
# Speed: 2.8ms preprocess, 75.4ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 73.2ms
# Speed: 2.8ms preprocess, 73.2ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 74.4ms
# Speed: 2.6ms preprocess, 74.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 74.1ms
# Speed: 3.0ms preprocess, 74.1ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 74.3ms
# Speed: 2.7ms preprocess, 74.3ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 2 keyboards, 65.0ms
# Speed: 2.7ms preprocess, 65.0ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 73.9ms
# Speed: 2.8ms preprocess, 73.9ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 2 keyboards, 66.3ms
# Speed: 2.7ms preprocess, 66.3ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 73.3ms
# Speed: 2.7ms preprocess, 73.3ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 71.7ms
# Speed: 2.8ms preprocess, 71.7ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 2 keyboards, 65.8ms
# Speed: 2.8ms preprocess, 65.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 2 keyboards, 73.6ms
# Speed: 2.8ms preprocess, 73.6ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 person, 72.1ms
# Speed: 2.7ms preprocess, 72.1ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 keyboard, 1 book, 124.3ms
# Speed: 3.2ms preprocess, 124.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 couch, 2 laptops, 63.8ms
# Speed: 2.8ms preprocess, 63.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 person, 1 bed, 2 laptops, 1 keyboard, 73.2ms
# Speed: 3.2ms preprocess, 73.2ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 bed, 1 laptop, 1 keyboard, 64.5ms
# Speed: 2.3ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 bed, 1 laptop, 1 keyboard, 75.5ms
# Speed: 2.9ms preprocess, 75.5ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 couch, 1 bed, 1 laptop, 78.3ms
# Speed: 2.8ms preprocess, 78.3ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 tv, 1 laptop, 61.4ms
# Speed: 2.1ms preprocess, 61.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 130.6ms
# Speed: 3.3ms preprocess, 130.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 laptop, 64.9ms
# Speed: 2.8ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 bed, 1 laptop, 124.7ms
# Speed: 13.7ms preprocess, 124.7ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 2 beds, 1 laptop, 73.7ms
# Speed: 2.5ms preprocess, 73.7ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 2 beds, 1 laptop, 69.7ms
# Speed: 2.3ms preprocess, 69.7ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 bed, 1 laptop, 76.2ms
# Speed: 3.0ms preprocess, 76.2ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 laptop, 78.2ms
# Speed: 3.1ms preprocess, 78.2ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 laptop, 72.4ms
# Speed: 2.9ms preprocess, 72.4ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 bed, 1 laptop, 73.7ms
# Speed: 2.6ms preprocess, 73.7ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 laptop, 72.4ms
# Speed: 2.9ms preprocess, 72.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 laptop, 72.8ms
# Speed: 2.9ms preprocess, 72.8ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 laptop, 72.4ms
# Speed: 3.1ms preprocess, 72.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 bed, 1 laptop, 71.9ms
# Speed: 2.7ms preprocess, 71.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 laptop, 72.0ms
# Speed: 2.2ms preprocess, 72.0ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 laptop, 100.1ms
# Speed: 3.8ms preprocess, 100.1ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 laptop, 61.3ms
# Speed: 2.4ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 laptop, 58.9ms
# Speed: 2.1ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 laptop, 59.6ms
# Speed: 2.9ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 couch, 1 laptop, 60.3ms
# Speed: 2.3ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 tv, 1 laptop, 62.6ms
# Speed: 2.6ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 59.3ms
# Speed: 2.6ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 116.8ms
# Speed: 17.0ms preprocess, 116.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bottle, 1 laptop, 1 keyboard, 116.4ms
# Speed: 6.5ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 67.0ms
# Speed: 2.6ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 110.9ms
# Speed: 3.2ms preprocess, 110.9ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 76.0ms
# Speed: 2.6ms preprocess, 76.0ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 75.7ms
# Speed: 2.6ms preprocess, 75.7ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 132.5ms
# Speed: 4.8ms preprocess, 132.5ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 78.1ms
# Speed: 3.1ms preprocess, 78.1ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 73.6ms
# Speed: 3.4ms preprocess, 73.6ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 1 cell phone, 75.5ms
# Speed: 3.0ms preprocess, 75.5ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 75.1ms
# Speed: 3.0ms preprocess, 75.1ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 74.0ms
# Speed: 3.1ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 72.9ms
# Speed: 3.5ms preprocess, 72.9ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 72.7ms
# Speed: 2.6ms preprocess, 72.7ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 63.2ms
# Speed: 2.1ms preprocess, 63.2ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 72.6ms
# Speed: 2.4ms preprocess, 72.6ms inference, 1.4ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 63.7ms
# Speed: 3.0ms preprocess, 63.7ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 71.3ms
# Speed: 2.9ms preprocess, 71.3ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 mouse, 1 keyboard, 73.5ms
# Speed: 2.9ms preprocess, 73.5ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 71.9ms
# Speed: 2.7ms preprocess, 71.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 1 cell phone, 86.1ms
# Speed: 3.3ms preprocess, 86.1ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 116.6ms
# Speed: 14.7ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 1 cell phone, 102.1ms
# Speed: 14.0ms preprocess, 102.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 keyboard, 114.3ms
# Speed: 18.5ms preprocess, 114.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 115.8ms
# Speed: 15.8ms preprocess, 115.8ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 70.3ms
# Speed: 2.7ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 60.9ms
# Speed: 2.6ms preprocess, 60.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 keyboard, 130.0ms
# Speed: 3.0ms preprocess, 130.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 64.4ms
# Speed: 2.8ms preprocess, 64.4ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 125.6ms
# Speed: 14.1ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 132.6ms
# Speed: 4.1ms preprocess, 132.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 1 book, 61.3ms
# Speed: 2.3ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 keyboard, 74.1ms
# Speed: 2.7ms preprocess, 74.1ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 keyboard, 1 book, 73.9ms
# Speed: 2.7ms preprocess, 73.9ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 keyboard, 73.4ms
# Speed: 3.1ms preprocess, 73.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 keyboard, 62.8ms
# Speed: 2.2ms preprocess, 62.8ms inference, 1.4ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 tv, 1 keyboard, 63.4ms
# Speed: 2.4ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 tv, 1 keyboard, 75.5ms
# Speed: 3.4ms preprocess, 75.5ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 67.7ms
# Speed: 3.1ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 keyboard, 1 book, 94.6ms
# Speed: 5.4ms preprocess, 94.6ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 73.4ms
# Speed: 2.7ms preprocess, 73.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 keyboard, 1 cell phone, 1 book, 96.0ms
# Speed: 2.9ms preprocess, 96.0ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 1 cell phone, 68.0ms
# Speed: 2.8ms preprocess, 68.0ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 1 cell phone, 1 book, 74.8ms
# Speed: 3.0ms preprocess, 74.8ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 62.7ms
# Speed: 2.6ms preprocess, 62.7ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 67.7ms
# Speed: 2.6ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 cell phone, 1 book, 74.9ms
# Speed: 2.7ms preprocess, 74.9ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 1 book, 112.9ms
# Speed: 12.2ms preprocess, 112.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 cell phone, 1 book, 129.9ms
# Speed: 10.5ms preprocess, 129.9ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 1 book, 77.6ms
# Speed: 2.8ms preprocess, 77.6ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 133.5ms
# Speed: 7.4ms preprocess, 133.5ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 74.9ms
# Speed: 2.9ms preprocess, 74.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 76.3ms
# Speed: 3.0ms preprocess, 76.3ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 87.2ms
# Speed: 4.8ms preprocess, 87.2ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 1 book, 74.1ms
# Speed: 3.0ms preprocess, 74.1ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 74.3ms
# Speed: 3.1ms preprocess, 74.3ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 75.4ms
# Speed: 2.9ms preprocess, 75.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 64.1ms
# Speed: 2.2ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 73.8ms
# Speed: 3.1ms preprocess, 73.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 74.2ms
# Speed: 3.0ms preprocess, 74.2ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 1 book, 74.3ms
# Speed: 2.8ms preprocess, 74.3ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 75.2ms
# Speed: 2.8ms preprocess, 75.2ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 74.9ms
# Speed: 2.9ms preprocess, 74.9ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 76.1ms
# Speed: 2.9ms preprocess, 76.1ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 2 books, 75.8ms
# Speed: 2.8ms preprocess, 75.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 2 books, 78.2ms
# Speed: 3.3ms preprocess, 78.2ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 1 book, 75.4ms
# Speed: 3.0ms preprocess, 75.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 2 books, 67.4ms
# Speed: 3.0ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 1 book, 74.9ms
# Speed: 3.3ms preprocess, 74.9ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 74.0ms
# Speed: 2.8ms preprocess, 74.0ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 113.3ms
# Speed: 13.9ms preprocess, 113.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 112.0ms
# Speed: 3.2ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 2 books, 135.4ms
# Speed: 5.9ms preprocess, 135.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 1 book, 64.4ms
# Speed: 2.6ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 2 books, 73.1ms
# Speed: 2.9ms preprocess, 73.1ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 1 book, 76.0ms
# Speed: 3.1ms preprocess, 76.0ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 1 book, 133.5ms
# Speed: 10.6ms preprocess, 133.5ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 1 book, 136.8ms
# Speed: 2.9ms preprocess, 136.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 1 book, 123.4ms
# Speed: 10.2ms preprocess, 123.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 117.0ms
# Speed: 15.3ms preprocess, 117.0ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 keyboards, 1 book, 130.3ms
# Speed: 11.8ms preprocess, 130.3ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 keyboard, 122.4ms
# Speed: 13.9ms preprocess, 122.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 tv, 124.1ms
# Speed: 3.4ms preprocess, 124.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 1 book, 113.3ms
# Speed: 23.0ms preprocess, 113.3ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 mouse, 1 keyboard, 1 book, 64.2ms
# Speed: 2.6ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 2 keyboards, 1 book, 77.3ms
# Speed: 3.2ms preprocess, 77.3ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 laptops, 1 keyboard, 75.7ms
# Speed: 3.0ms preprocess, 75.7ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 book, 113.7ms
# Speed: 10.4ms preprocess, 113.7ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 61.9ms
# Speed: 2.4ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 59.8ms
# Speed: 2.3ms preprocess, 59.8ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 book, 112.4ms
# Speed: 5.6ms preprocess, 112.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 2 books, 115.2ms
# Speed: 15.2ms preprocess, 115.2ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 63.0ms
# Speed: 2.7ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 98.7ms
# Speed: 3.3ms preprocess, 98.7ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 93.7ms
# Speed: 3.4ms preprocess, 93.7ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 72.8ms
# Speed: 3.0ms preprocess, 72.8ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 2 books, 81.6ms
# Speed: 3.1ms preprocess, 81.6ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 88.0ms
# Speed: 2.5ms preprocess, 88.0ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 80.0ms
# Speed: 3.5ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 73.1ms
# Speed: 3.2ms preprocess, 73.1ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 60.3ms
# Speed: 2.7ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 78.9ms
# Speed: 2.8ms preprocess, 78.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 laptop, 1 book, 82.2ms
# Speed: 2.8ms preprocess, 82.2ms inference, 1.4ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 2 beds, 1 laptop, 1 book, 76.4ms
# Speed: 3.0ms preprocess, 76.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 bed, 1 laptop, 1 book, 72.3ms
# Speed: 2.9ms preprocess, 72.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# [INFO] Video processing complete.
